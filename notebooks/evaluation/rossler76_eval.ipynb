# %%
from collections import defaultdict
from pathlib import Path

import colorcet as cc
import equinox as eqx
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
import numpy as np
from dynamical_systems.analysis import lyapunov_gr
from dynamical_systems.analysis.jacobian import jacobian
from dynamical_systems.continuous import Rossler76, solve_ode
from dynamical_systems.metrics import (
    cosine_similarity as cosine_similarity,
    maximum_mean_discrepancy as maximum_mean_discrepancy,
    mean_squared_error as mean_squared_error,
    sinkhorn_divergence as sinkhorn_divergence,
)
from dynamical_systems.transforms import TransformedODE
from dynamics_discovery.data import TimeSeriesDataset
from dynamics_discovery.io import load_model
from dynamics_discovery.metrics.error import relative_error_norm
from dynamics_discovery.models import NeuralODE
from matplotlib_utils.axes_setters import set_labels
from matplotlib_utils.plots import colored_scatterplot, plot_line_and_band
from ott.utils import batched_vmap
from tqdm import tqdm


plt.style.use("matplotlib_utils.styles.dash_gridded")
jax.config.update("jax_enable_x64", True)

EXP_TYPES_ALL = ("vanilla", "jacobian", "tangent_evolution", "neighborhood", "normal")
EXP_TYPES = ("vanilla", "jacobian", "tangent_evolution")  # , "neighborhood")
COLOR_DICT = dict(
    zip(
        EXP_TYPES_ALL,
        ("royalblue", "limegreen", "darkorange", "orangered", "saddlebrown"),
    )
)
LABEL_DICT = dict(
    zip(
        EXP_TYPES_ALL,
        (
            "Vanilla",
            "Jacobian matching",
            "Tangent Evolution matching",
            "Neighborhood-based (ours)",
            "Normal-based (ours)",
        ),
    )
)

# %%
downsample = 40
noise = 0.0
train_length = 2

datadir = Path("../../data")

dataset_train, transform = (
    TimeSeriesDataset.from_hdf5(datadir / "rossler76_train.hdf5")
    .downsample(downsample)
    .add_noise(noise)
    .standardize()
)
dataset_test = (
    TimeSeriesDataset.from_hdf5(datadir / "rossler76_test.hdf5")
    .add_noise(noise)
    .apply_transform(transform)
)

# %%
def load_experiment(
    exp_type: str,
    key: int,
    downsample: int = downsample,
    train_length: int = 2,
    noise: float = 0.0,
    rootdir=Path("../../results/best/rossler76"),
) -> NeuralODE:
    loaddir = rootdir / f"downsample={downsample}/len={train_length}/{exp_type}"
    if exp_type == "neighborhood":
        loaddir = loaddir / "weight=1.0"
    model_paths = list(loaddir.glob(f"*_noise={noise}_key={key}*"))

    if len(model_paths) == 0:
        raise ValueError("No models found with the given conditions")
    elif len(model_paths) > 1:
        raise ValueError("Multiple models found with the given conditions!")
    else:
        print(model_paths[0])
        return load_model(model_paths[0])

# %%
key = 10
traj_idx = 100
t_traj, u_traj = dataset_test[traj_idx]

n_short = 750
t_short_norm = np.arange(n_short) * 0.01
t_short, u_short = t_traj[:n_short], u_traj[:n_short]

u_short_dict = defaultdict(list)
for exp_type in tqdm(EXP_TYPES):
    model = load_experiment(exp_type, key)
    u_short_dict[exp_type] = solve_ode(model, t_short, u_short[0], rtol=1e-4, atol=1e-6)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
#  33%|███▎      | 1/3 [00:00<00:00,  9.46it/s]
# ../../results/best/rossler76/downsample=40/len=2/vanilla/lr=0.005_noise=0.0_key=10
# ../../results/best/rossler76/downsample=40/len=2/jacobian/lr=0.0005_noise=0.0_key=10
# 100%|██████████| 3/3 [00:00<00:00,  9.66it/s]
# ../../results/best/rossler76/downsample=40/len=2/tangent_evolution/lr=0.005_noise=0.0_key=10

# %%
plot_kwargs = {"linewidth": 1.5, "alpha": 0.8}

fig, axes = plt.subplots(3, 1, figsize=(8, 4), sharex=True)
for i, (ax, y_name) in enumerate(zip(axes.flat, ("x", "y", "z"))):
    ax.plot(
        t_short_norm,
        u_short[:, i],
        "--",
        color="black",
        linewidth=2.25,
        alpha=0.5,
        label="Ground truth",
    )
    for exp_type, u_pred in u_short_dict.items():
        ax.plot(
            t_short_norm,
            u_pred[:, i],
            color=COLOR_DICT[exp_type],
            label=LABEL_DICT[exp_type],
            **plot_kwargs,
        )
    ax.set_ylabel(y_name, rotation="horizontal")
ax.set_xlabel(r"$\bar{t}=\lambda_{max}t$")
fig.align_ylabels()
fig.legend(
    *ax.get_legend_handles_labels(), loc="outside center right", fontsize="medium"
)
fig.suptitle(f"Short term predictions: {train_length=}, seed={key}", fontsize="large")
# Out:
# Text(0.5, 0.98, 'Short term predictions: train_length=2, seed=10')

# %%
@eqx.filter_jit
def solve_batch(model, t, u0_batch):
    def _solve(u0_):
        return solve_ode(model, t, u0_, rtol=1e-4, atol=1e-6, max_steps=None)

    return batched_vmap(_solve, batch_size=5000)(u0_batch)


@eqx.filter_jit
def calculate_metric_short(model, metric_fn=mean_squared_error):
    t_short = dataset_test.t[0, :n_short]
    u_short_batch = dataset_test.u[:, :n_short]

    u_pred_batch = solve_batch(model, t_short, u_short_batch[:, 0])
    return metric_fn(u_short_batch, u_pred_batch, axis=-1)


metric_short_dict = defaultdict(list)
for exp_type in tqdm(EXP_TYPES):
    metric_short_dict[exp_type] = [
        jnp.mean(calculate_metric_short(load_experiment(exp_type, k)), axis=0)
        for k in (0, 10, 20, 30, 40)
    ]
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# ../../results/best/rossler76/downsample=2/len=2/vanilla/lr=0.005_noise=0.0_key=0
# ../../results/best/rossler76/downsample=2/len=2/vanilla/lr=0.005_noise=0.0_key=10
# ../../results/best/rossler76/downsample=2/len=2/vanilla/lr=0.005_noise=0.0_key=20
# ../../results/best/rossler76/downsample=2/len=2/vanilla/lr=0.005_noise=0.0_key=30
# ../../results/best/rossler76/downsample=2/len=2/vanilla/lr=0.005_noise=0.0_key=40
#  25%|██▌       | 1/4 [00:19<00:59, 19.72s/it]
# ../../results/best/rossler76/downsample=2/len=2/jacobian/lr=0.002_noise=0.0_key=0
# ../../results/best/rossler76/downsample=2/len=2/jacobian/lr=0.002_noise=0.0_key=10
# ../../results/best/rossler76/downsample=2/len=2/jacobian/lr=0.002_noise=0.0_key=20
# ../../results/best/rossler76/downsample=2/len=2/jacobian/lr=0.002_noise=0.0_key=30
# ../../results/best/rossler76/downsample=2/len=2/jacobian/lr=0.002_noise=0.0_key=40
#  50%|█████     | 2/4 [00:30<00:29, 14.74s/it]
# ../../results/best/rossler76/downsample=2/len=2/tangent_evolution/lr=0.002_noise=0.0_key=0
# ../../results/best/rossler76/downsample=2/len=2/tangent_evolution/lr=0.002_noise=0.0_key=10
# ../../results/best/rossler76/downsample=2/len=2/tangent_evolution/lr=0.002_noise=0.0_key=20
# ../../results/best/rossler76/downsample=2/len=2/tangent_evolution/lr=0.002_noise=0.0_key=30
# ../../results/best/rossler76/downsample=2/len=2/tangent_evolution/lr=0.002_noise=0.0_key=40
#  75%|███████▌  | 3/4 [00:42<00:13, 13.06s/it]
# ../../results/best/rossler76/downsample=2/len=2/neighborhood/weight=1.0/neighbors=30/lr=0.005_noise=0.0_key=0_config
# ../../results/best/rossler76/downsample=2/len=2/neighborhood/weight=1.0/neighbors=30/lr=0.005_noise=0.0_key=10_config
# ../../results/best/rossler76/downsample=2/len=2/neighborhood/weight=1.0/neighbors=30/lr=0.005_noise=0.0_key=20_config
# ../../results/best/rossler76/downsample=2/len=2/neighborhood/weight=1.0/neighbors=30/lr=0.005_noise=0.0_key=30_config
# ../../results/best/rossler76/downsample=2/len=2/neighborhood/weight=1.0/neighbors=30/lr=0.005_noise=0.0_key=40_config
# 100%|██████████| 4/4 [00:53<00:00, 13.38s/it]

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 4))
for exp_type, metric_short in metric_short_dict.items():
    plot_line_and_band(
        ax,
        t_short_norm[::10],
        np.mean(metric_short, axis=0)[::10],
        np.std(metric_short, axis=0)[::10],
        color=COLOR_DICT[exp_type],
        label=LABEL_DICT[exp_type],
    )
ax.legend(fontsize="small")
ax.set_xlabel(r"$\bar{t}=\lambda_{max}t$")
ax.set_ylabel("MSE (↓)")
ax.set_yscale("log", base=10)

# %%
metric_short_dict = defaultdict(list)
for exp_type in tqdm(EXP_TYPES):
    metric_short_dict[exp_type] = [
        calculate_metric_short(
            load_experiment(exp_type, k), metric_fn=cosine_similarity
        )
        for k in (0, 10, 20, 30, 40)
    ]
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# ../../results/best/rossler76/downsample=2/len=2/vanilla/lr=0.005_noise=0.0_key=0
# ../../results/best/rossler76/downsample=2/len=2/vanilla/lr=0.005_noise=0.0_key=10
# ../../results/best/rossler76/downsample=2/len=2/vanilla/lr=0.005_noise=0.0_key=20
# ../../results/best/rossler76/downsample=2/len=2/vanilla/lr=0.005_noise=0.0_key=30
# ../../results/best/rossler76/downsample=2/len=2/vanilla/lr=0.005_noise=0.0_key=40
#  25%|██▌       | 1/4 [00:19<00:58, 19.49s/it]
# ../../results/best/rossler76/downsample=2/len=2/jacobian/lr=0.002_noise=0.0_key=0
# ../../results/best/rossler76/downsample=2/len=2/jacobian/lr=0.002_noise=0.0_key=10
# ../../results/best/rossler76/downsample=2/len=2/jacobian/lr=0.002_noise=0.0_key=20
# ../../results/best/rossler76/downsample=2/len=2/jacobian/lr=0.002_noise=0.0_key=30
# ../../results/best/rossler76/downsample=2/len=2/jacobian/lr=0.002_noise=0.0_key=40
#  50%|█████     | 2/4 [00:30<00:29, 14.59s/it]
# ../../results/best/rossler76/downsample=2/len=2/tangent_evolution/lr=0.002_noise=0.0_key=0
# ../../results/best/rossler76/downsample=2/len=2/tangent_evolution/lr=0.002_noise=0.0_key=10
# ../../results/best/rossler76/downsample=2/len=2/tangent_evolution/lr=0.002_noise=0.0_key=20
# ../../results/best/rossler76/downsample=2/len=2/tangent_evolution/lr=0.002_noise=0.0_key=30
# ../../results/best/rossler76/downsample=2/len=2/tangent_evolution/lr=0.002_noise=0.0_key=40
#  75%|███████▌  | 3/4 [00:41<00:12, 12.99s/it]
# ../../results/best/rossler76/downsample=2/len=2/neighborhood/weight=1.0/neighbors=30/lr=0.005_noise=0.0_key=0_config
# ../../results/best/rossler76/downsample=2/len=2/neighborhood/weight=1.0/neighbors=30/lr=0.005_noise=0.0_key=10_config
# ../../results/best/rossler76/downsample=2/len=2/neighborhood/weight=1.0/neighbors=30/lr=0.005_noise=0.0_key=20_config
# ../../results/best/rossler76/downsample=2/len=2/neighborhood/weight=1.0/neighbors=30/lr=0.005_noise=0.0_key=30_config
# ../../results/best/rossler76/downsample=2/len=2/neighborhood/weight=1.0/neighbors=30/lr=0.005_noise=0.0_key=40_config
# 100%|██████████| 4/4 [00:53<00:00, 13.35s/it]

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 4))
for exp_type, metric_short in metric_short_dict.items():
    plot_line_and_band(
        ax,
        t_short_norm[::10],
        np.mean(metric_short, axis=0)[::10],
        np.std(metric_short, axis=0)[::10],
        color=COLOR_DICT[exp_type],
        label=LABEL_DICT[exp_type],
    )
ax.legend(fontsize="small")
ax.set_xlabel(r"$\bar{t}=\lambda_{max}t$")
ax.set_ylabel("Cosine similarity (↑)")
# Out:
# Text(0, 0.5, 'Cosine similarity (↑)')

# %%
import ott


# idx_long = np.asarray([1, 5, 10, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]) - 1
idx_long = np.asarray([1, 10, 100, 1000, 10000]) - 1
t_norm = np.arange(dataset_test.t.shape[0]) * 0.01
t_long, t_long_norm = dataset_test.t[0, idx_long], t_norm[idx_long]


@jax.jit
def sinkhorn(x, y):
    return ott.tools.sinkhorn_divergence.sinkhorn_divergence(
        ott.geometry.pointcloud.PointCloud,
        x=x,
        y=y,
        epsilon=1.0,
        relative_epsilon="std",
        solve_kwargs={"lse_mode": True, "max_iterations": 2000, "threshold": 0.001},
    )[0]


def calculate_metric_long(model, metric_fn=sinkhorn):
    u_long_batch = dataset_test.u[:, idx_long]
    u_long_pred = solve_batch(model, t_long, u_long_batch[:, 0])
    metric = []
    for i in range(1, len(idx_long)):
        metric.append(metric_fn(u_long_batch[:, i], u_long_pred[:, i]))
    return np.asarray(metric)

# %%
metric_long_dict = defaultdict(list)
for exp_type in tqdm(EXP_TYPES):
    metric_long_dict[exp_type] = [
        calculate_metric_long(load_experiment(exp_type, k)) for k in (0, 10, 20, 30, 40)
    ]
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# ../../results/best/rossler76/downsample=2/len=2/vanilla/lr=0.005_noise=0.0_key=0
# ../../results/best/rossler76/downsample=2/len=2/vanilla/lr=0.005_noise=0.0_key=10
# ../../results/best/rossler76/downsample=2/len=2/vanilla/lr=0.005_noise=0.0_key=20
# ../../results/best/rossler76/downsample=2/len=2/vanilla/lr=0.005_noise=0.0_key=30
# ../../results/best/rossler76/downsample=2/len=2/vanilla/lr=0.005_noise=0.0_key=40
#  25%|██▌       | 1/4 [02:14<06:44, 134.91s/it]
# ../../results/best/rossler76/downsample=2/len=2/jacobian/lr=0.002_noise=0.0_key=0
# ../../results/best/rossler76/downsample=2/len=2/jacobian/lr=0.002_noise=0.0_key=10
# ../../results/best/rossler76/downsample=2/len=2/jacobian/lr=0.002_noise=0.0_key=20
# ../../results/best/rossler76/downsample=2/len=2/jacobian/lr=0.002_noise=0.0_key=30
# ../../results/best/rossler76/downsample=2/len=2/jacobian/lr=0.002_noise=0.0_key=40
#  50%|█████     | 2/4 [04:28<04:28, 134.39s/it]
# ../../results/best/rossler76/downsample=2/len=2/tangent_evolution/lr=0.002_noise=0.0_key=0
# ../../results/best/rossler76/downsample=2/len=2/tangent_evolution/lr=0.002_noise=0.0_key=10
# ../../results/best/rossler76/downsample=2/len=2/tangent_evolution/lr=0.002_noise=0.0_key=20
# ../../results/best/rossler76/downsample=2/len=2/tangent_evolution/lr=0.002_noise=0.0_key=30
# ../../results/best/rossler76/downsample=2/len=2/tangent_evolution/lr=0.002_noise=0.0_key=40
#  75%|███████▌  | 3/4 [06:43<02:14, 134.43s/it]
# ../../results/best/rossler76/downsample=2/len=2/neighborhood/weight=1.0/neighbors=30/lr=0.005_noise=0.0_key=0_config
# ../../results/best/rossler76/downsample=2/len=2/neighborhood/weight=1.0/neighbors=30/lr=0.005_noise=0.0_key=10_config
# ../../results/best/rossler76/downsample=2/len=2/neighborhood/weight=1.0/neighbors=30/lr=0.005_noise=0.0_key=20_config
# ../../results/best/rossler76/downsample=2/len=2/neighborhood/weight=1.0/neighbors=30/lr=0.005_noise=0.0_key=30_config
# ../../results/best/rossler76/downsample=2/len=2/neighborhood/weight=1.0/neighbors=30/lr=0.005_noise=0.0_key=40_config
# 100%|██████████| 4/4 [09:01<00:00, 135.25s/it]

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 4))
for exp_type, metric_long in metric_long_dict.items():
    ax.errorbar(
        t_long_norm[1:],
        np.mean(metric_long, axis=0),
        np.std(metric_long, axis=0),
        capsize=3,
        color=COLOR_DICT[exp_type],
        label=LABEL_DICT[exp_type],
    )
ax.legend(fontsize="small")
ax.set_xlabel(r"$\bar{t}=\lambda_{max}t$")
ax.set_ylabel("Sinkhorn Divergence (↓)")
ax.set_yscale("log", base=10)
ax.set_xscale("log", base=10)

# %%
import ott


@jax.jit
def sinkhorn(x, y):
    return ott.tools.sinkhorn_divergence.sinkhorn_divergence(
        ott.geometry.pointcloud.PointCloud,
        x=x,
        y=y,
        epsilon=1.0,
        relative_epsilon="std",
        solve_kwargs={"lse_mode": True, "max_iterations": 2000, "threshold": 0.001},
    )[0]

# %%
metric_long_dict = defaultdict(list)
for exp_type in tqdm(EXP_TYPES):
    metric_long_dict[exp_type] = [
        calculate_metric_long(load_experiment(exp_type, k), metric_fn=sinkhorn)
        for k in (0, 10, 20)
    ]
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# ../../results/best/rossler76/downsample=2/len=2/vanilla/lr=0.005_noise=0.0_key=0
# ../../results/best/rossler76/downsample=2/len=2/vanilla/lr=0.005_noise=0.0_key=10
# ../../results/best/rossler76/downsample=2/len=2/vanilla/lr=0.005_noise=0.0_key=20
#  25%|██▌       | 1/4 [01:23<04:09, 83.28s/it]
# ../../results/best/rossler76/downsample=2/len=2/jacobian/lr=0.002_noise=0.0_key=0
# ../../results/best/rossler76/downsample=2/len=2/jacobian/lr=0.002_noise=0.0_key=10
# ../../results/best/rossler76/downsample=2/len=2/jacobian/lr=0.002_noise=0.0_key=20
#  50%|█████     | 2/4 [02:43<02:43, 81.73s/it]
# ../../results/best/rossler76/downsample=2/len=2/tangent_evolution/lr=0.002_noise=0.0_key=0
# ../../results/best/rossler76/downsample=2/len=2/tangent_evolution/lr=0.002_noise=0.0_key=10
# ../../results/best/rossler76/downsample=2/len=2/tangent_evolution/lr=0.002_noise=0.0_key=20
#  75%|███████▌  | 3/4 [04:04<01:21, 81.02s/it]
# ../../results/best/rossler76/downsample=2/len=2/neighborhood/weight=1.0/neighbors=30/lr=0.005_noise=0.0_key=0_config
# ../../results/best/rossler76/downsample=2/len=2/neighborhood/weight=1.0/neighbors=30/lr=0.005_noise=0.0_key=10_config
# ../../results/best/rossler76/downsample=2/len=2/neighborhood/weight=1.0/neighbors=30/lr=0.005_noise=0.0_key=20_config
# 100%|██████████| 4/4 [05:26<00:00, 81.62s/it]

# %%
metric_long_dict["vanilla"]
# Out:
# [array([-3.32588840e-06,  1.85147492e-05,  5.01509704e-04,  4.95707667e-04]),
#  array([-1.51143431e-06,  6.65551474e-05,  9.76734957e-04,  9.80983606e-04]),
#  array([-4.01948038e-06,  2.34229018e-05,  2.00033608e-04,  1.91950281e-03])]

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 4))
for exp_type in ("vanilla", "neighborhood"):
    metric_long = metric_long_dict[exp_type]
    for i in range(5):
        ax.scatter(
            t_long_norm[1:][1:],  # [np.array([4, 7, 10])],
            metric_long[i][1:],  # [np.array([4, 7, 10])],
            color=COLOR_DICT[exp_type],
            label=LABEL_DICT[exp_type],
            alpha=0.9,
            marker="o",
            facecolor="None",
            s=50,
        )
    ax.plot(
        t_long_norm[1:][1:],  # [np.array([4, 7, 10])],
        np.median(metric_long, axis=0)[1:],  # [np.array([4, 7, 10])],
        color=COLOR_DICT[exp_type],
        label=LABEL_DICT[exp_type],
        alpha=0.9,
    )
# ax.legend(fontsize="small")
ax.set_xlabel(r"$\bar{t}=\lambda_{max}t$")
ax.set_ylabel("Sinkhorn Divergence (↓)")
ax.set_yscale("log", base=10)
ax.set_xscale("log", base=10)
# ax.set_ylim((1e-7, 5e-3))
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
metric_long_dict["neighborhood"]
# Out:
# [array([-1.37852929e-05, -3.08022232e-05,  2.63611271e-05, -4.69968185e-05,
#          1.97173586e-04,  1.47669849e-04,  6.40197133e-04,  7.52422179e-04,
#          9.69009546e-04, -2.77558154e-04, -9.44386670e-04]),
#  array([ 1.05143864e-05,  7.15206060e-05, -1.36359444e-04,  3.22996225e-06,
#         -1.75747184e-04,  3.32583061e-04, -2.23520597e-04,  1.31327135e-03,
#          1.00485449e-03,  1.68592106e-03, -1.59668648e-03]),
#  array([ 1.02207718e-05, -6.81207234e-05,  7.00150023e-05, -1.06110138e-05,
#          1.74111319e-05,  1.83864760e-05,  1.19639677e-03, -4.32892422e-04,
#         -1.14806100e-03,  7.99147348e-04, -2.06891215e-04])]

# %%
key = 0
jacobian_batch = eqx.filter_vmap(jacobian, in_axes=(None, None, 0))
jac_true = jacobian_batch(
    TransformedODE(Rossler76(), transform), 0.0, dataset_test.u[:, 0]
)


@eqx.filter_jit
def compute_jac_err(model):
    jac_pred = jacobian_batch(model, 0.0, dataset_test.u[:, 0])
    return relative_error_norm(jac_pred, jac_true, axis=(-2, -1))


jac_logerr_dict = defaultdict(list)
for exp_type in tqdm(EXP_TYPES):
    jac_logerr_dict[exp_type] = np.log10(
        compute_jac_err(load_experiment(exp_type, key))
    )
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# ../../results/best/rossler76/downsample=2/len=2/vanilla/lr=0.005_noise=0.0_key=0
# 100%|██████████| 4/4 [00:00<00:00,  9.52it/s]
# ../../results/best/rossler76/downsample=2/len=2/jacobian/lr=0.002_noise=0.0_key=0
# ../../results/best/rossler76/downsample=2/len=2/tangent_evolution/lr=0.002_noise=0.0_key=0
# ../../results/best/rossler76/downsample=2/len=2/neighborhood/weight=1.0/neighbors=30/lr=0.005_noise=0.0_key=0_config

# %%
fig = colored_scatterplot(
    [dataset_test.u[:, 0].T] * len(EXP_TYPES),
    [jac_logerr_dict[exp_type] for exp_type in EXP_TYPES],
    figsize=(10, 6),
    s=1,
    cmap=cc.cm.rainbow4,
    alpha=0.9,
)
for i, exp_type in enumerate(EXP_TYPES):
    fig.axes[i].set_title(LABEL_DICT[exp_type], fontsize="medium")
    set_labels(fig.axes[i], ["x", "y", "z"])
fig.axes[-1].set_ylabel(
    r"$\log_{10}||\mathbf{J}_{true}-\mathbf{J}_{pred}||_F\;/\;||\mathbf{J}_{true}||_F$"
)
# Out:
# Text(0, 0.5, '$\\log_{10}||\\mathbf{J}_{true}-\\mathbf{J}_{pred}||_F\\;/\\;||\\mathbf{J}_{true}||_F$')

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 4))
for exp_type, log_err in jac_logerr_dict.items():
    ax.hist(
        log_err,
        bins=50,
        label=LABEL_DICT[exp_type],
        color=COLOR_DICT[exp_type],
        alpha=0.8,
    )
ax.legend()

# %%
ind_lya_max = 1000
lya_dict = jnp.load(datadir / "rossler76_lyapunov_test.npz")


@eqx.filter_jit
def calculate_lyapunov(model):
    lyas = batched_vmap(
        lambda u0_: lyapunov_gr(
            model, u0_, lya_dict["t"][:ind_lya_max], rtol=1e-4, atol=1e-6, max_steps=64
        )[0],
        batch_size=5000,
    )(dataset_test.u[:, 0])
    return lyas

# %%
lyapunov_dict = defaultdict(list)

for exp_type in tqdm(EXP_TYPES):
    lyapunov_dict[exp_type] = calculate_lyapunov(load_experiment(exp_type, key))
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# ../../results/best/rossler76/downsample=2/len=2/vanilla/lr=0.005_noise=0.0_key=0
#  25%|██▌       | 1/4 [03:11<09:34, 191.44s/it]
# ../../results/best/rossler76/downsample=2/len=2/jacobian/lr=0.002_noise=0.0_key=0
#  50%|█████     | 2/4 [05:20<05:09, 154.98s/it]
# ../../results/best/rossler76/downsample=2/len=2/tangent_evolution/lr=0.002_noise=0.0_key=0
#  75%|███████▌  | 3/4 [07:30<02:23, 143.55s/it]
# ../../results/best/rossler76/downsample=2/len=2/neighborhood/weight=1.0/neighbors=30/lr=0.005_noise=0.0_key=0_config
# 100%|██████████| 4/4 [10:01<00:00, 150.25s/it]

# %%
fig, axes = plt.subplots(3, 1, figsize=(8, 4))

hist_kwargs = {"bins": 50, "alpha": 0.7}
# ax.set_yscale("symlog", base=10)

lya_known = lya_dict["lyas_literature"]
lyas_true = lya_dict["lyas"][:, ind_lya_max - 1]
for i, ax in enumerate(axes.flat):
    ax.hist(
        lyas_true[:, i],
        color="gray",
        label="Ground truth",
        **hist_kwargs,
    )
    for exp_type, v in lyapunov_dict.items():
        ax.hist(
            v[:, -1, i],
            color=COLOR_DICT[exp_type],
            label=LABEL_DICT[exp_type],
            **hist_kwargs,
        )

    ax.axvline(
        x=lya_known[i],
        color="brown",
        linewidth=2.0,
        linestyle="--",
        label="Literature",
        alpha=0.7,
    )
    ax.set_xlabel(rf"$\lambda_{i + 1}(t)$")

fig.legend(
    *axes[1].get_legend_handles_labels(), loc="outside center right", fontsize="medium"
)
fig.supylabel("Counts", fontsize="medium")
fig.align_ylabels()
fig.suptitle(f"Lyapunov spectrum: train length = {train_length}, noise = {noise}")
# Out:
# Text(0.5, 0.98, 'Lyapunov spectrum: train length = 2, noise = 0.0')
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
